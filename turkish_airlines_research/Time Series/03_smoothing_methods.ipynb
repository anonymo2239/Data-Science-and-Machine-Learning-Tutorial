# %% [markdown]
# # Smoothing Methods

# %% [markdown]
# ![image.png](image18.png)

# %% [markdown]
# Hepsine Holt-Winters denmesiyle beraber genellikle Triple'a Holt-Winters denir.
# TES, durağan olmayan serilerde trendi ve mevsimselliği yakalayabilir.

# %% [markdown]
# **10'dan fazla model görücez, en iyi model bizim verimizde en iyi tahmini yapan modeldir.**

# %% [markdown]
# ## SES

# %% [markdown]
# Hareketli ortalama ve weighted average ler de smoothing yapıyorlardı. bunlar da aynı görevi görüyorlar ve exponantial ler.

# %% [markdown]
# ![image.png](image19.png)

# %% [markdown]
# pazartesi = a*pazarın gerçek değeri(learning değer) + (1-a)*pazarın tahmin edilen değeri(remembering değer)

# %% [markdown]
# learning e ne kadar ağırlık verirsek remembering e o kadar az ağırlık veririz.

# %% [markdown]
# Bu yöntem trend ve mevsimsellik içermeyen zaman serileri için uygundur.

# %% [markdown]
# ![image.png](image20.png)

# %% [markdown]
# **Alpha artıkça gerçek değerin daha yakınında bir yumuşatma yapar. diğer bir deyişle daha iyi öğrenir. daha az YUMUŞATIR.**
