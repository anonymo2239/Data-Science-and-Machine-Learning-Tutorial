# %%
# Herhangi bir makine öğrenimi projesindeki ilk adım, verilere aşina olmaktır.
# Bunun için Pandas kütüphanesini kullanacaksınız. Pandalar, veri bilim adamlarının verileri keşfetmek ve işlemek için kullandıkları birincil araçtır.

# %%
import pandas as pd

# %%
houses = pd.read_csv("C:/Users/Alperen Arda/OneDrive/Desktop/GitHub/Data-Science-and-Machine-Learning-Tutorial/Datasets/melb_data.csv")

# %%
houses.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# Verilen veriye ait sonuçlar, her sütun için 8 farklı değeri gösterir. Bu değerler şunlardır:

# count: Eksik olmayan değerlerin sayısını gösterir.
# mean: Değerlerin ortalamasıdır.
# std: Değerlerin ne kadar yayıldığını gösteren standart sapmadır.
# min: En küçük değeri temsil eder.
# 25% (1. çeyrek): Verilerin %25'inden büyük, %75'inden küçük olan değerdir.
# 50% (medyan): Ortanca değeri gösterir, yani verilerin yarısı bu değerden küçük, yarısı büyüktür.
# 75% (3. çeyrek): Verilerin %75'inden büyük, %25'inden küçük olan değerdir.
# max: En büyük değeri temsil eder.
# Eksik veriler, örneğin tek odalı bir evde ikinci yatak odası ölçülerinin toplanmaması gibi çeşitli nedenlerle ortaya çıkabilir.

# %%
houses.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
# Bu metin, veri setinizdeki en yeni evin aslında çok da yeni olmadığını belirtiyor ve bunun nedenleri üzerine düşünmenizi istiyor. İki olası açıklama sunuluyor:

# Açıklama 1: Verinin toplandığı bölgede yeni evler inşa edilmemiş olabilir.
# Açıklama 2: Veriler uzun zaman önce toplanmış olabilir, bu yüzden veri setinde daha yeni evler yer almıyor olabilir.
# Sorulan sorular şunlar:

# Eğer sebep birinci açıklama (bölgede yeni evler inşa edilmemiş olması) ise, bu durum modelinize olan güveninizi etkiler mi? Peki, ikinci açıklama (verilerin eski olması) olursa ne düşünürdünüz?

# Hangi açıklamanın daha olası olduğunu anlamak için veriyi nasıl inceleyebilirsiniz?

# Bu sorularla, veri setinizin doğruluğunu ve güvenilirliğini sorgulamanız isteniyor. Ayrıca, verinin toplandığı zaman aralığını ve bölgesel inşaat faaliyetlerini inceleyerek hangi açıklamanın daha mantıklı olduğunu bulmanız gerekiyor.

# %%
# Araştırma Yöntemleri
# Hangi açıklamanın daha olası olduğunu anlamak için iki yöntem öneriliyor:

# Veri Seti ve Meta Verilerini İnceleme: Veri setinin ne zaman yayımlandığına bakmak önemlidir. Örneğin, veri setinin yaklaşık 6 yıl önce yayımlandığı ve 2010'dan sonra inşa edilen veya satılan yeni evlerin olmadığını gözlemlemek, verilerin eski olduğunu ve piyasa koşullarını artık doğru bir şekilde yansıtamayacağını gösterir.

# Görsel Temsil: Yıllara göre inşa edilen evlerin dağılımını gösteren bir histogram veya Kernel Yoğunluk Tahmini (KDE) grafiği, veri setinin hangi dönemi kapsadığını anlamak için kullanılabilir.

# Bu açıklamalar, modelinizin güvenilirliği ve uygulanabilirliği hakkında bilinçli kararlar almanıza yardımcı olur.

# %%
pd.DataFrame.hist(houses, 'YearBuilt')
# Out:
# array([[<Axes: title={'center': 'YearBuilt'}>]], dtype=object)

# %%
houses['YearBuilt'].plot.kde()
# Out:
# <Axes: ylabel='Density'>
