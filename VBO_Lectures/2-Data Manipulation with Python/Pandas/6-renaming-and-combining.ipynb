# %%
import pandas as pd

# %%
my_estate = pd.read_csv("C:/Users/Alperen Arda/OneDrive/Desktop/GitHub/Data-Science-and-Machine-Learning-Tutorial/Datasets/melb_data.csv")

# %%
my_estate.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
my_estate.rename(columns={"Bathroom": "Restroom"}) # rename() fonksiyonu index ismi değiştirmeye yarar
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Restroom  Car  Landsize  \
# ...

# %%
my_estate.loc[my_estate.Bathroom.idxmax()]
# Out:
# Suburb                         Preston
# Address                  421 Murray Rd
# Rooms                                4
# Type                                 h
# Price                         760000.0
# Method                              PI
# SellerG                          Barry
# Date                        22/05/2016
# Distance                           8.8
# Postcode                        3072.0
# Bedroom2                           9.0
# Bathroom                           8.0
# Car                                7.0
# Landsize                        1254.0
# BuildingArea                     280.0
# YearBuilt                       1928.0
# CouncilArea                    Darebin
# Lattitude                     -37.7367
# Longtitude                    144.9895
# Regionname       Northern Metropolitan
# Propertycount                  14577.0
# Name: 4980, dtype: object

# %%
# rename(), sırasıyla bir dizin veya sütun anahtar sözcüğü parametresi belirterek dizin veya sütun değerlerini yeniden adlandırmanıza olanak tanır. 
# Çeşitli giriş formatlarını destekler, ancak genellikle Python sözlüğü en kullanışlı olanıdır. 
# Dizinin bazı öğelerini yeniden adlandırmak için bunu kullanan bir örneği burada bulabilirsiniz.

# %%
my_estate.rename(index={0: 'firstindex', 1: 'secondindex'})
# Out:
#                     Suburb           Address  Rooms Type      Price Method  \
# firstindex      Abbotsford      85 Turner St      2    h  1480000.0      S
# secondindex     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2               Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3               Abbotsford  40 Federation La      3    h   850000.0     PI
# 4               Abbotsford       55a Park St      4    h  1600000.0     VB
# ...                    ...               ...    ...  ...        ...    ...
# 13575        Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576         Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577         Williamstown       83 Power St      3    h  1170000.0      S
# 13578         Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579           Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
# Sütun adlarını sıkça değiştirirsin, ama satır indekslerini nadiren değiştirirsin. Bunun için set_index() genellikle daha uygundur.
# Hem satır hem de sütun indekslerinin kendi adları olabilir. Bu adları değiştirmek için rename_axis() metodunu kullanabilirsin.

# %%
my_estate.rename_axis("street", axis='rows').rename_axis("fields", axis='columns')
# set_index methodu, "olan sütunu" index yapar. rename_axis ise indexlere isim vermek için yapılır.
# Out:
# fields         Suburb           Address  Rooms Type      Price Method  \
# street
# 0          Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          Abbotsford       55a Park St      4    h  1600000.0     VB
# ...               ...               ...    ...  ...        ...    ...
# 13575   Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576    Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577    Williamstown       83 Power St      3    h  1170000.0      S
# 13578    Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579      Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# fields   SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. 
# Pandas has three core methods for doing this. In order of increasing complexity, these are concat(), join(), and merge(). 
# Most of what merge() can do can also be done more simply with join(), so we will omit it and focus on the first two functions here.

# %%
# CONCAT
# concat() fonksiyonu varsayılan olarak verileri (satırları) birleştirir, yani satırları alt alta ekleyerek tek bir DataFrame oluşturur.
# Çalışmayan ÖRNEK
# canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
# british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

# pd.concat([canadian_youtube, british_youtube])
# reviews değil pd kullanılıyor.

# %%
# JOIN
# join() fonksiyonu, iki DataFrame'i ortak bir indekse göre birleştirir. 
# Bu örnekte, Kanada (left) ve İngiltere (right) YouTube videolarını title (başlık) ve trending_date (trend olma tarihi) sütunlarına göre birleştiriyoruz.

# İlk olarak, her iki DataFrame'de de set_index() kullanarak title ve trending_date sütunlarını indeks olarak ayarlıyoruz.
# Sonra, join() ile bu iki DataFrame'i bu ortak indeksler üzerinden birleştiriyoruz.
# lsuffix='_CAN' ve rsuffix='_UK' parametreleri, aynı isimdeki sütunlar için ayırt edici ekler ekleyerek çakışmayı önler.
# Sonuç olarak, aynı gün hem Kanada hem de İngiltere'de trend olan videoları birleştirmiş oluyoruz.

# %%
# Çalışmayan ÖRNEK
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])

# left.join(right, lsuffix='_CAN', rsuffix='_UK')
