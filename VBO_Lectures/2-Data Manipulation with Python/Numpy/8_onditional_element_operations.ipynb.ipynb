# %%
import numpy as np 
v = np.array([1, 2, 3, 4, 5])

# %%
v > 3
# Out:
# array([False, False, False,  True,  True])

# %%
v[v > 3]
# Out:
# array([4, 5])

# %%
v[v == 3]
# Out:
# array([3])

# %% [markdown]
# # Mathematical Operators

# %%
v / 5
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %%
v - 1
# Out:
# array([0, 1, 2, 3, 4])

# %%
v * 5 / 10 - 1
# Out:
# array([-0.5,  0. ,  0.5,  1. ,  1.5])

# %% [markdown]
# ufunc (Universal Function), NumPy'da element bazlı işlemler yapan temel matematiksel fonksiyonlardır.

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([99, 98, 97])

# %%
np.subtract(arr1, arr2)
# Out:
# array([-98, -96, -94])

# %%
np.add(arr1, arr2)
# Out:
# array([100, 100, 100])

# %%
np.divide(arr1, arr2)
# Out:
# array([0.01010101, 0.02040816, 0.03092784])

# %%
arr1 = np.array([1, 4, 3])
arr2 = np.array([3, 4, 5])

# %%
np.power(arr1, arr2)
# Out:
# array([  1, 256, 243])

# %%
np.mod(arr1, arr2)
# Out:
# array([1, 0, 3])

# %%
np.absolute(np.array([-2, -213])) # mutlak deger
# Out:
# array([  2, 213])

# %%
np.sin(360)
# Out:
# 0.9589157234143065

# %%
np.cos(0)
# Out:
# 1.0

# %%
v = np.array([1, 2, 3])

# %%
np.log2(v)
# Out:
# array([0.       , 1.       , 1.5849625])

# %%
np.log10(100000)
# Out:
# 5.0

# %%
# ?np
# Out:
# Type:        module
# String form: <module 'numpy' from 'C:\\Users\\Alperen Arda\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\numpy\\__init__.py'>
# File:        c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages\numpy\__init__.py
# Docstring:
# NumPy
# =====
#
# Provides
#   1. An array object of arbitrary homogeneous items
#   2. Fast mathematical operations over arrays
#   3. Linear Algebra, Fourier Transforms, Random Number Generation
#
# How to use the documentation
# ----------------------------
# Documentation is available in two forms: docstrings provided
# with the code, and a loose standing reference guide, available from
# `the NumPy homepage <https://numpy.org>`_.
#
# We recommend exploring the docstrings using
# `IPython <https://ipython.org>`_, an advanced Python shell with
# TAB-completion and introspection capabilities.  See below for further
# instructions.
#
# ...

# %% [markdown]
# # Buradan numpy in dokumantasyonuna ulasabiliriz

# %%
help(np.sort)
# Out:
# Help on _ArrayFunctionDispatcher in module numpy:
#
# sort(a, axis=-1, kind=None, order=None)
#     Return a sorted copy of an array.
#
#     Parameters
#     ----------
#     a : array_like
#         Array to be sorted.
#     axis : int or None, optional
#         Axis along which to sort. If None, the array is flattened before
#         sorting. The default is -1, which sorts along the last axis.
#     kind : {'quicksort', 'mergesort', 'heapsort', 'stable'}, optional
#         Sorting algorithm. The default is 'quicksort'. Note that both 'stable'
#         and 'mergesort' use timsort or radix sort under the covers and, in general,
#         the actual implementation will vary with data type. The 'mergesort' option
#         is retained for backwards compatibility.
#
#         .. versionchanged:: 1.15.0.
#            The 'stable' option was added.
#
#     order : str or list of str, optional
#         When `a` is an array with fields defined, this argument specifies
# ...

# %% [markdown]
# # Cheat sheet

# %% [markdown]
# ![image.png](attachment:7ac28928-93a0-4c85-a55c-afbac8124913.png)

# %% [markdown]
# # PYTHON UN TÜM KÜTÜPHANELERİ İÇİN CHEAT SHEET VAR
