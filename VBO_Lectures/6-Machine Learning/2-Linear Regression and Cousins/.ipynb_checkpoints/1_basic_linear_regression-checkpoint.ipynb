# %% [markdown]
# ![image.png](image1.png)

# %% [markdown]
# Doğrusallıkta kalmak bizlere daha çok yorumlanabilirlik şansı vermektedir. Yorumlanabilirlik açısından en zengin modeller bu modellerdir.

# %% [markdown]
# # Basit Doğrusal Regresyon

# %% [markdown]
# Temel amaç, bağımlı ve bağımsız değişken arasındaki ilişkiyi ifade eden doğrusal fonksiyonu bulmaktır.

# %% [markdown]
# ![image.png](image2.png)

# %% [markdown]
# x, bağımsız değişkenleri temsil eder. y, bağımlı değişkeni temsil eder. Buradaki ß modele göre optimum seviyeye getirilir. Epsilon işareti ise hata payını verir. (Stokastik model formulü)

# %% [markdown]
# ![image.png](image3.png)

# %% [markdown]
# ![image.png](image4.png)

# %% [markdown]
# ![image.png](image5.png)

# %% [markdown]
# ![image.png](image6.png)

# %% [markdown]
# ## Uygulama

# %%
import pandas as pd
ad = pd.read_csv("Advertising.csv")
df = ad.copy()
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df = df.iloc[:, 1:len(df)] # index i sutun olarak aldigi icin
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.isnull().values.any() # degerlerde hic eksik deger yok
# Out:
# False

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(data=df, kind='reg');

# %%
sns.jointplot(x='TV', y='sales', data=df, kind='reg')

# %% [markdown]
# TV ve radio arasındaki korelasyon çok düşük. Bundan dolayı tv yi sales modelini modellemek için kullanmakla beraber radio değişkenini DE kullanabiliriz.

# %% [markdown]
# ## Statsmodels ile modelleme

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.25.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.14.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\alperen arda\appdata\roaming\python\python311\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\alperen arda\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)

# %%
import statsmodels.api as sm

X = df[["TV"]]
X[0:5]
# Out:
#       TV
# 0  230.1
# 1   44.5
# 2   17.2
# 3  151.5
# 4  180.8

# %%
X = sm.add_constant(X)

# %%
X[0:5]
# Out:
#    const     TV
# 0    1.0  230.1
# 1    1.0   44.5
# 2    1.0   17.2
# 3    1.0  151.5
# 4    1.0  180.8

# %%
y = df['sales']
y[0:5]
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
lm = sm.OLS(y, X)

# %%
model = lm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Tue, 31 Dec 2024   Prob (F-statistic):           1.47e-42
# Time:                        21:00:10   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ![image.png](image7.png)

# %% [markdown]
# Kısacası, bu model satışlardaki değişkenliğin %61.2’sini açıklayabiliyor. R kare formulü gereği değişken arttıkça artacaktır. O yüzden Düzeltilmiş R kare daha düzgün bir metrik olarak karşımıza çıkar.

# %% [markdown]
# Kısacası burada ilişkisi yüksek olan bir değişken bulduk(TV) ve bu değişkeni feature variable olarak alıp target variable(sales) ile modele soktuk. Scikit-learn kadar geniş çaplı bir kütüphane olmasa da scikit-learn den daha ayrıntılı bilgi vermektedir.

# %% [markdown]
# ![image.png](image8.png)

# %% [markdown]
# ![image.png](image9.png)

# %% [markdown]
# Bu değerlere bakacak olursak 'y = ß0 + x*ß1' denklemine göre coef (coefficients) katsayıları verir.
#
# Standart hata (0.458):
#
# * Katsayının tahminindeki hata miktarını gösterir. Daha düşük standart hata, tahminin daha güvenilir olduğunu ifade eder.
#
# t-istatistiği (15.360) ve p-değeri (0.000):
#
# * Sabit terimin anlamlı olup olmadığını test eder. Burada, p-değeri 0.05'ten küçük olduğu için sabit terim istatistiksel olarak anlamlıdır.
#
# [6.130, 7.935]:
#
# * %95 güven aralığı, sabit terimin gerçek değerinin bu aralıkta olduğundan emin olunabileceğini gösterir.
#
# ve sonuç olarak denklemimiz y = 7.0326 + 0.0475*x olur. Bu denklemi kullanarak yeni değerler tahmin ederiz.

# %%
import statsmodels.formula.api as smf
lm = smf.ols('sales ~ TV', df)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Tue, 31 Dec 2024   Prob (F-statistic):           1.47e-42
# Time:                        21:00:10   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.params # bu kullanim direkt katsayilari veriyor
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
model.summary().tables[1] # 2. tabloyu verir.
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model.conf_int() 

# Güven aralığı, bir katsayının gerçek değerinin belirli bir olasılıkla (örneğin, %95 güven düzeyi) yer aldığı tahmin edilen aralıktır. 
# Güven aralıkları, modelin tahmin ettiği katsayıların belirsizlik düzeyini ifade eder.
# Tabloda, her katsayı için alt (0) ve üst (1) sınırları verilmiştir:

# Intercept örneği için(Sabit Terim):
# Güven aralığı: [6.1297, 7.9355]
# Bu, %95 güven düzeyiyle sabit terimin gerçek değerinin bu aralıkta olduğunu gösterir.
# Yani, sabit terim için 6.1297 ile 7.9355 arasında bir değer alma olasılığı %95’tir.
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
print("f_pvalue: ", "%.4f" % model.f_pvalue)
# Out:
# f_pvalue:  0.0000

# %%
print("fvalue: ", "%.2f" % model.fvalue)
# Out:
# fvalue:  312.14

# %%
print("tvalue: ", "%.2f" % model.tvalues[0])
# Out:
# tvalue:  15.36
# C:\Users\Alperen Arda\AppData\Local\Temp\ipykernel_14388\4239432737.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("tvalue: ", "%.2f" % model.tvalues[0])

# %%
model.mse_model # ortalamasi 14 olan bir degisken icin bu hata cok kotu
# Out:
# 3314.6181668686486

# %% [markdown]
# Kısacası modeli falan kurduk ama modelin doğruluğuna yönelik istatistiksel çıkarımları da ele almalıyız.

# %%
model.rsquared
# Out:
# 0.611875050850071

# %%
model.rsquared_adj
# Out:
# 0.6099148238341623

# %%
model.fittedvalues[0:5] # modelin tahmin ettigi degerler
# Out:
# 0    17.970775
# 1     9.147974
# 2     7.850224
# 3    14.234395
# 4    15.627218
# dtype: float64

# %%
y[0:5] # modelin gercek degerleri
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
# Bu modelin denklemini yazalim(mulakat sorusu!!)

# %%
print("Sales = " + str("%.2f" % model.params[0]) + " + TV" + " * " + str("%.2f" % model.params[1]))
# Out:
# Sales = 7.03 + TV * 0.05
# C:\Users\Alperen Arda\AppData\Local\Temp\ipykernel_14388\416924917.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Sales = " + str("%.2f" % model.params[0]) + " + TV" + " * " + str("%.2f" % model.params[1]))

# %%
print("Sales = {:.2f} + TV * {:.2f}".format(model.params.iloc[0], model.params.iloc[1]))
# Out:
# Sales = 7.03 + TV * 0.05

# %% [markdown]
# Diyelim ki satış müdürü bize diyecek: ben TV reklamları için 10 bin dolar ayırdım. Bunun satışa etkisi ne olur? dicek. Biz de oluşturduğumuz bu modelde yerine koycaz:

# %%
print(7.03 + 10000*0.05) # dicez
# Out:
# 507.03

# %%
g = sns.regplot(x="TV", y="sales", data=df, ci=None, scatter_kws={'color':'r', 's':9})
g.set_title("Model Denklemi: Sales = 7.03 + TV*0.05")
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV Harcamaları")
plt.xlim(-10, 310)
plt.ylim(bottom=0);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       3 g.set_ylabel("Satış Sayısı")
#       4 g.set_xlabel("TV Harcamaları")
# ----> 5 plt.xlim(-10, 310)
#       6 plt.ylim(bottom=0);
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Sklearn ile modelleme

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['TV']]
y = df[['sales']]
reg = LinearRegression() # artik anlasilmistir fakat yine hatirlatayim: once linear regression dan nesne olusturuyoruz. sonra modeli olusturuyoruz
model = reg.fit(X, y)

# %%
model.intercept_ # ß0 katsayisini verir.
# Out:
# array([7.03259355])

# %%
model.coef_ # ß1 katsayisini verir.
# Out:
# array([[0.04753664]])

# %%
model.score(X, y) # basari orani degil, r kare degeridir
# Out:
# 0.611875050850071

# %%
model.predict(X)[0:10]
# Out:
# array([[17.97077451],
#        [ 9.14797405],
#        [ 7.85022376],
#        [14.23439457],
#        [15.62721814],
#        [ 7.44616232],
#        [ 9.76595037],
#        [12.74649773],
#        [ 7.44140866],
#        [16.53041431]])
