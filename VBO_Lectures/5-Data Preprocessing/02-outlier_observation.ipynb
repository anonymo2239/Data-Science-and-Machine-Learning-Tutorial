# %% [markdown]
# **Outlier Observation**

# %% [markdown]
# Veride genel eğilimin oldukça dışına çıkan gözlemlerdir.

# %% [markdown]
# **Aykırı gözlemleri neden düzeltmeliyiz?**

# %% [markdown]
# Genellenebilirlik kaygısı ile oluşturulan kural setlerini ya da fonksiyonları yanıltır. Yanlılığa sebep olur.

# %% [markdown]
# ![image.png](attachment:c75386a1-98f0-48a8-9978-008ff09d8217.png)

# %% [markdown]
# 3 tane aykırı gözlem yüzünden verinin genel eğiminin yönü değişmiş

# %% [markdown]
# **Aykırı gözlem olduğunu nasıl anlarız?**

# %% [markdown]
# 1) Sektör Bilgisi
#
#    Örneğin bir ev fiyat tahmin modelinde 1000 metrekarelik evleri modellemeye almamak. Çünkü 1000 metrekare çok uçuk bir örnek ve Türkiye'deki evlerin %1'ini bile oluşturmadığı için modele almak uygun değil.

# %% [markdown]
# ![image.png](attachment:373fe88c-8417-428d-bfa9-d310868e6dfc.png)

# %% [markdown]
# 2) Standart Sapma Yaklaşımı
#
#    Bir değişkenin ortalamasının üzerine aynı değişkenin standart sapması hesaplanarak eklenir. 1,2 ya da 3 standart sapma değeri ortalama üzerine eklenerek ortaya çıkan bu değer eşik değer olarak düşünülür ve bu değerden yukarıda ya da aşağıda olan değerler aykırı değer olarak tanımlanır.

# %% [markdown]
# ![image.png](attachment:9573c3a0-193c-44fe-8283-1a47493caf7d.png)

# %% [markdown]
# 3) Z-Skoru Yaklaşımı
#
#    Standart sapma yöntemine benzer şekilde çalışır. Değişken standart normal dağılıma uyarlanır, yani standartlaştırılır. Sonrasında -örneğin- dağılımın sağından ve solundan -+ 2,5 değerine göre bir eşik değer konulur ve bu değerin üzerinde ya da altında olan değerler aykırı değer olarak işaretlenir.

# %% [markdown]
# ![image.png](attachment:a629435f-ebbd-408b-a49e-f2a6f0b3d429.png)

# %% [markdown]
# 4) Boxplot (interquartile range - IQR) Yöntemi
#
#    En sık kullanılan yöntemlerden birisidir. Değişkenin değerleri küçükten büyüğe sıralanır. Çeyrekliklerine (yüzdekliklerine) yani Q1,Q3 değerlerine karşılık değerler üzerinden bir eşik değer hesaplanır ve bu eşik değere göre aykırı değer tanımı yapılır.

# %% [markdown]
# ![image.png](attachment:6f405a8d-159c-43c5-8dac-de4eb68bb97e.png)

# %% [markdown]
# Hemen makine öğrenmesine atlamamalıyız. Veri setini incelemeliyiz. Genellikle 1. ve 4. yöntemlerle yol alacağız.
