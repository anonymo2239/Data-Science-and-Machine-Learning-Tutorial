# %% [markdown]
# # Missing Value Analysis

# %% [markdown]
# İncelenen veri setinde gözlemlerde eksiklik olması durumunu ifade etmektedir.

# %% [markdown]
# Yine silme veya doldurma yöntemlerini ele alıcaz.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Kural:
#
# Veri setindeki eksikliğin yapısal bir eksiklik olup olmadığının bilinmesi gerekir.

# %% [markdown]
# ![image5.png](attachment:c376b026-a08b-4718-b8e9-2e56d6b4d493.png)

# %% [markdown]
# Örneğin bu durum yapısal bir eksikliktir. Rastgele oluşmamıştır.

# %% [markdown]
# ### 2. Kural:
#
# NA her zaman eksiklik anlamına gelmez.

# %% [markdown]
# ![image6.png](attachment:65df0273-6dd2-4b58-8fe1-4ce1a34de5a8.png)

# %% [markdown]
# Burda müşterinin kredi kartı var ama harcama yapmamış olabilir. Bundan dolayı buraya sıfır yazılabilir.

# %% [markdown]
# ### 3. Kural:
#
# Bilgi Kaybı!!

# %% [markdown]
# ![image7.png](image7.png)

# %% [markdown]
# Örnek olarak 100 sütunluk bir satırımız var. Bir değişken için bu satırı silersek 99 sütunu(bilgiyi) kaybetmiş olucaz. O yüzden silmeye gerek olmayabilir.

# %% [markdown]
# ## Eksik veri türleri nelerdir?

# %% [markdown]
# ![image.png](image8.png)

# %% [markdown]
# Burada en kolayı tümüyle raslantısal kayıptır. Çünkü genellikle silerek işi hemen bitirebiliriz.

# %% [markdown]
# ### Peki bu verinin hangi veri türü olduğunu nasıl anlarız?

# %% [markdown]
# ![image.png](image9.png)

# %% [markdown]
# The idea of the imputation is both seductive and dangerous

# %% [markdown]
# ### Yöntemler nelerdir?

# %% [markdown]
# ![image.png](imagea1.png)
