# %% [markdown]
# **Veri önişleme ve veri manipülasyonu konuları aynı olarak düşünülebilir. Fakat veri manipülasyonu daha çok genel ön hazırlığı ifade ederken veri önişleme makine öğrenmesi adımı için zorunlu olan ön hazırlıkları ifade eder.**

# %% [markdown]
# # Veri mi Model mi?

# %% [markdown]
# Makine öğrenmesi modelinin amacı genellenebilir yapılar ortaya koymaktır.

# %% [markdown]
# Belirli olaylar gözlemlendiğinde belirli tahmin sonuçları vermektedir.

# %% [markdown]
# ![image.png](attachment:b34e3b6e-a1ec-4953-a873-109bfd490705.png)

# %% [markdown]
# Bu çelişkili bir bilgi olduğu için gürültülü bir bilgidir.

# %% [markdown]
# Veya örneğin bir bebek biberonunun 1 milyon TL olması gibi. Bu durumlar aykırı değildir gürültülüdür.

# %% [markdown]
# ![image.png](attachment:0df13904-3612-4a2f-874d-63f29c7d67b8.png)

# %% [markdown]
# Aykırı ve eksik gözlem örnekleri

# %% [markdown]
# ![image.png](attachment:6db83d7d-6690-45a2-bbd9-602726255696.png)

# %% [markdown]
# Diğer veri önişleme bölümleri
